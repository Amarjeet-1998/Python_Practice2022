# %% [markdown]
# <a href="https://colab.research.google.com/github/Amarjeet-1998/Python_Practice2022/blob/main/python_practice_01oct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tuple1 = (10, 20, 30, 40, 50)
tuple1 = tuple1[::-1]
print(tuple1)
# Out:
# (50, 40, 30, 20, 10)

# %%
tuple1 =("orange", [10,20,30], (5,15,25))
tuple1[0]
# Out:
# 'orange'

# %%
tuple1[1]
# Out:
# [10, 20, 30]

# %%
tuple1[1][1]
# Out:
# 20

# %%
print(tuple1[1][1])
# Out:
# 20

# %%
tuple1 = (50, )
print(tuple1)
# Out:
# (50,)

# %%
tuple1 = (10,20,30,40)

a, b, c, d = tuple1

print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 20
# 30
# 40

# %%
tuple1 = (11, 22)
tuple2 = (99, 88)

tuple1, tuple2 = tuple2, tuple1
print(tuple2)
print(tuple1)
# Out:
# (11, 22)
# (99, 88)

# %%
tuple1 = (11,22,33,44,55,66,77,88)
tuple2 = tuple1[3:-1]
print(tuple2)
# Out:
# (44, 55, 66, 77)

# %%
tuple1 = (11, [22, 33], 44,55)
tuple1[1][0] =222
print(tuple1)
# Out:
# (11, [222, 33], 44, 55)

# %%
tuple1 = (('a', 23),('b', 37),('c',11),('d',29))
tuple1 = tuple(sorted(list(tuple1), key = lambda x: x[1]))
print(tuple1)
# Out:
# (('c', 11), ('a', 23), ('d', 29), ('b', 37))

# %%
tuple1 = (50, 10, 60, 70, 50)
print(tuple1.count(50))
# Out:
# 2

# %%
def check(t):
  return all(i == t[0] for i in t)

tuple1 = (45, 45, 45, 45)
print(check(tuple1))
# Out:
# True

# %%
from datetime import datetime

date_string = 'Feb 25 2020  4:20PM'
datetime_object = datetime.strptime(date_string, '%b %d %Y %I:%M%p')
print(datetime_object)
# Out:
# 2020-02-25 16:20:00

# %%
from datetime import datetime, timedelta

given_date = datetime(2020, 2, 25)
print("Given date")
print(given_date)

days_to_subtract = 7
res_date = given_date - timedelta(days=days_to_subtract)
print("New Date")
print(res_date)
# Out:
# Given date
# 2020-02-25 00:00:00
# New Date
# 2020-02-18 00:00:00

# %%
from datetime import datetime
given_date = datetime(2020, 2, 25)
print("Given date is")
print(given_date.strftime("%A %d %B %Y"))
# Out:
# Given date is
# Tuesday 25 February 2020

# %%
from datetime import datetime

given_date = datetime(2020, 7, 26)

#to get weekday as integer
print(given_date.today().weekday())

#to get the english name of the weekday
print(given_date.strftime("%A"))
# Out:
# 3
# Sunday

# %%
from datetime import datetime, timedelta

given_date = datetime(2020, 3, 22, 10, 00, 00)
print("Given date")
print(given_date)

days_to_add = 7
res_date = given_date + timedelta(days=days_to_add, hours = 12)
print("New Delhi")
print(res_date)
# Out:
# Given date
# 2020-03-22 10:00:00
# New Delhi
# 2020-03-29 22:00:00

# %%
import time

milliseconds = int(round(time.time() * 1000))
print(milliseconds)
# Out:
# 1664461415436

# %%
from datetime import datetime

given_date = datetime(2020, 2, 25)
string_date = given_date.strftime("%Y-%m-%d %H:%M:%S")
print(string_date)
# Out:
# 2020-02-25 00:00:00

# %%
from datetime import datetime

from dateutil.relativedelta import relativedelta

given_date = datetime(2020, 2, 25).date()

months_to_add = 4
new_date = given_date + relativedelta(months=+ months_to_add)
print(new_date)
# Out:
# 2020-06-25

# %%
from datetime import datetime

date_1 = datetime(2020, 2, 25).date()

date_2 = datetime(2020, 9, 17).date()

delta = None
if date_1 > date_2:
  print("date_1 is greater")
  delta = date_1 - date_2
else:
  print("date_2 is greater")
  delta = date_2 - date_1

print("Difference is", delta.days, "days")
# Out:
# date_2 is greater
# Difference is 205 days

# %%
class Vehicle:
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

modelX = Vehicle(240, 18)
print(modelX.max_speed, modelX.mileage)
# Out:
# 240 18

# %%
class Vehicle:
  pass

# %%
class Vehicle:

    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

# %%
class Vehicle:

    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

class Bus(Vehicle):
    pass

School_bus = Bus("School Volvo", 180, 12)
print("Vehicle Name:", School_bus.name, "Speed:", School_bus.max_speed, "Mileage:", School_bus.mileage)
# Out:
# Vehicle Name: School Volvo Speed: 180 Mileage: 12

# %%
class Vehicle:
    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

    def seating_capacity(self, capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers"

# %%
class Vehicle:
    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

    def seating_capacity(self, capacity):
        return f"The seating capacity of a {self.name} is {capacity} passengers"

class Bus(Vehicle):
    # assign default value to capacity
    def seating_capacity(self, capacity=50):
        return super().seating_capacity(capacity=50)

School_bus = Bus("School Volvo", 180, 12)
print(School_bus.seating_capacity())
# Out:
# The seating capacity of a School Volvo is 50 passengers

# %%
class Vehicle:

    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

class Bus(Vehicle):
    pass

class Car(Vehicle):
    pass

# %%
class Vehicle:
    # Class attribute
    color = "White"

    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

class Bus(Vehicle):
    pass

class Car(Vehicle):
    pass

School_bus = Bus("School Volvo", 180, 12)
print(School_bus.color, School_bus.name, "Speed:", School_bus.max_speed, "Mileage:", School_bus.mileage)
# Out:
# White School Volvo Speed: 180 Mileage: 12

# %%
class Vehicle:
    def __init__(self, name, mileage, capacity):
        self.name = name
        self.mileage = mileage
        self.capacity = capacity

    def fare(self):
        return self.capacity * 100

class Bus(Vehicle):
    pass

School_bus = Bus("School Volvo", 12, 50)
print("Total Bus fare is:", School_bus.fare())
# Out:
# Total Bus fare is: 5000

# %%
class Vehicle:
    def __init__(self, name, mileage, capacity):
        self.name = name
        self.mileage = mileage
        self.capacity = capacity

class Bus(Vehicle):
    pass

School_bus = Bus("School Volvo", 12, 50)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(-6, 6, 200)

cos = np.cos(x)

plt.plot(x, cos)

# %%
x = np.linspace(-6, 6, 200)

sin = np.sin(x)

plt.plot(x, sin)

# %%
 x = np.linspace(-6, 6, 200)

cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos)
plt.plot(x, sin)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(-10, 10, 150)
cos = np.cos(x)
sin= np.sin(x)

# %%
plt.plot(x, cos, color='red',linewidth = 2.8, linestyle='--')

# %%
plt.plot(x, sin, linewidth = 3.5, linestyle='-.')

# %%
plt.plot(x, sin, linewidth = 3.5, linestyle=':')

# %%
plt.plot(x, sin, linewidth = 3.5, linestyle=':')
plt.plot(x, cos, linewidth = 3.5, linestyle='--')

# %%
plt.plot(x, cos,color='green' ,linewidth = 3.5, linestyle='-')
plt.text(-4,-0.3,'This text will be displayed across or plot', rotation=20, fontsize=14)
# Out:
# Text(-4, -0.3, 'This text will be displayed across or plot')

# %%
plt.plot(x, cos,color='green' ,linewidth = 3.5, linestyle='-')
plt.text(-7,0,'This text will be displayed across or plot', rotation=35, fontsize=14)
# Out:
# Text(-7, 0, 'This text will be displayed across or plot')

# %%
plt.plot(x, cos,color='green' ,linewidth = 3.5, linestyle='-')
plt.text(-8,-0,'This text will be displayed across or plot', fontsize=14)
# Out:
# Text(-8, 0, 'This text will be displayed across or plot')

# %%
plt.subplot(211)
plt.plot(x, cos, color='red', linewidth=2.8)
plt.text(-5, -0.5, 'this will run across our subplot', rotation=11, fontsize=14)

plt.subplot(212)
plt.plot(x, sin, color='green', linewidth = 3.8)
plt.text(-5, -0.5, 'this will run across our subplot', rotation=11, fontsize=14)
# Out:
# Text(-5, -0.5, 'this will run across our subplot')

# %%
x = np.linspace(-10, 10, 150)
cos = np.cos(x)
sin = np.sin(x)

plt.plot(x, cos, color='red', linewidth=3.0)

# %%
plt.plot(x, cos, color='red', linewidth =3.0)

plt.xlabel('X-axis')
plt.ylabel('cosx')
plt.title('Graph of x vs cosx')
# Out:
# Text(0.5, 1.0, 'Graph of x vs cosx')

# %%
plt.plot(x, cos, color='red', linewidth =3.0)

plt.xlabel('X-axis', fontsize=15, color='black')
plt.ylabel('cosx', fontsize=15, color='green')
plt.title('Graph of x vs cosx')
plt.grid(True)

# %%
plt.plot(x, cos, color='red', linewidth =3.0)

plt.xlabel('X-axis', fontsize=15, color='black')
plt.ylabel('cosx', fontsize=15, color='green')
plt.title('Graph of x vs cosx')
plt.grid(True)

plt.annotate('this is one max value', xy = (0,1), xytext=(5, 0.5), arrowprops= dict(facecolor='black', shrink =0.09))
# Out:
# Text(5, 0.5, 'this is one max value')

# %%
plt.plot(x, cos, color='red', linewidth =3.0)

plt.xlabel('X-axis', fontsize=15, color='black')
plt.ylabel('cosx', fontsize=15, color='green')
plt.title('Graph of x vs cosx')
plt.grid(True)

plt.annotate('this is one max value', xy = (0,1), xytext=(5, 0.5), arrowprops= dict(facecolor='black', shrink =0.09))
# Out:
# Text(5, 0.5, 'this is one max value')
